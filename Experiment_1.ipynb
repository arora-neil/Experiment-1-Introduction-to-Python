# %%
# Experiment 1- Introduction to python
# Neil Arora
x,y,z="apple","orange","cherry"
print(x,y,z,sep="\n")
# Out:
# apple
# orange
# cherry

# %%
x,y,z,w=2,2.5,"orange",True;
print(type(x),type(y),type(z),type(w),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b=10,5
print("Add=",a+b,"\nSub=",a-b,"\nMulti=",a*b,"\nDiv=",a/b,"\nexp=",a**b)
# Out:
# Add= 15
# Sub= 5
# Multi= 50
# Div= 2.0
# exp= 100000

# %%
a,b=int(input("ENTER VALUE OF A:")),int(input("ENTER VALUE OF B:"))
print("Add=",a+b,"\nSub=",a-b,"\nMulti=",a*b,"\nDiv=",a/b,"\nexp=",a**b)
# Out:
# ENTER VALUE OF A:3
# ENTER VALUE OF B:2
# Add= 5
# Sub= 1
# Multi= 6
# Div= 1.5
# exp= 9

# %%
r=float(input("Enter radius of circle:"))
print("Area of circle=",math.pi*r*r)
# Out:
# Enter radius of circle:1
# Area of circle= 3.141592653589793

# %%
import math
print("log 10=",math.log10(10))
# Out:
# log 10= 1.0

# %%
import math
print("sin 60=",math.sin(math.radians(90)))
# Out:
# sin 60= 1.0

# %%
a,b=float(input("ENTER VALUE OF A:")),float(input("ENTER VALUE OF B:"))
if b>a:
 print("b>a")
else:
 print("B is not greater then a")
# Out:
# ENTER VALUE OF A:10
# ENTER VALUE OF B:5
# B is not greater then a
